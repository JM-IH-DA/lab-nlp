# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# Loading and Exploring Data:

import pandas as pd

df = pd.read_csv('training.1600000.processed.noemoticon.csv', header=None, encoding='latin-1')

# %%
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']

# %%
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   id      1600000 non-null  int64
#  2   date    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df['target'].value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
# Selecting a subset of 20000 rows:

df_subset = df.sample(n=20000, random_state=42)

# %%
df_subset.head()
# Out:
#         target          id                          date      flag  \
# 541200       0  2200003196  Tue Jun 16 18:18:12 PDT 2009  NO_QUERY
# 750          0  1467998485  Mon Apr 06 23:11:14 PDT 2009  NO_QUERY
# 766711       0  2300048954  Tue Jun 23 13:40:11 PDT 2009  NO_QUERY
# 285055       0  1993474027  Mon Jun 01 10:26:07 PDT 2009  NO_QUERY
# 705995       0  2256550904  Sat Jun 20 12:56:51 PDT 2009  NO_QUERY
#
#                    user                                               text
# 541200  LaLaLindsey0609             @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750         sexygrneyes  @misstoriblack cool , i have no tweet apps  fo...
# 766711       sammydearr  @TiannaChaos i know  just family drama. its la...
# 285055      Lamb_Leanne  School email won't open  and I have geography ...
# 705995      yogicerdito                             upper airways problem

# %%
df_subset.shape
# Out:
# (20000, 6)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# Clean up function:

def clean_up(s):
    
    import re
    
    s = re.sub('http\S+|[\W\d]+', ' ',  s)
    s = re.sub('\s+', ' ', s)
    
    return s.lower()

# %%
# Tokenize function:

def tokenize(s):
    
    from nltk.tokenize import word_tokenize
    
    tokens = word_tokenize(s)
    
    return tokens

# %%
# Stem_and_lemmatize function:

def stem_and_lemmatize(l):
    
    from nltk.stem import PorterStemmer, WordNetLemmatizer
    from nltk.corpus import wordnet

    
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer() 
    
    stem_and_lemmatized = []
    
    for word in l:
        stemmed = stemmer.stem(word)
        lemmatized = lemmatizer.lemmatize(word)
        stem_and_lemmatized.append((stemmed,lemmatized))
        
    return stem_and_lemmatized

# %%
# Stopwords function:

def remove_stopwords(l):
    
    from nltk.corpus import stopwords
    
    without_sw = [word for word in l if not word in stopwords.words('english')]
    
    return without_sw

# %%
# Applying it to the text all together:

df_subset['text_processed'] = df_subset['text'].apply(clean_up)
df_subset['text_processed'] = df_subset['text_processed'].apply(tokenize)
df_subset['text_processed'] = df_subset['text_processed'].apply(stem_and_lemmatize)
df_subset['text_processed'] = df_subset['text_processed'].apply(remove_stopwords)

# %%
df_subset.head(15)
# Out:
#          target          id                          date      flag  \
# 541200        0  2200003196  Tue Jun 16 18:18:12 PDT 2009  NO_QUERY
# 750           0  1467998485  Mon Apr 06 23:11:14 PDT 2009  NO_QUERY
# 766711        0  2300048954  Tue Jun 23 13:40:11 PDT 2009  NO_QUERY
# 285055        0  1993474027  Mon Jun 01 10:26:07 PDT 2009  NO_QUERY
# 705995        0  2256550904  Sat Jun 20 12:56:51 PDT 2009  NO_QUERY
# 379611        0  2052380495  Sat Jun 06 00:32:16 PDT 2009  NO_QUERY
# 1189018       4  1983449090  Sun May 31 13:10:36 PDT 2009  NO_QUERY
# 667030        0  2245479748  Fri Jun 19 16:11:29 PDT 2009  NO_QUERY
# 93541         0  1770705699  Mon May 11 22:01:32 PDT 2009  NO_QUERY
# 1097326       4  1970386589  Sat May 30 03:39:34 PDT 2009  NO_QUERY
# 1380171       4  2052206835  Fri Jun 05 23:59:27 PDT 2009  NO_QUERY
# 1233933       4  1992273171  Mon Jun 01 08:29:05 PDT 2009  NO_QUERY
# 1495501       4  2069921255  Sun Jun 07 16:46:29 PDT 2009  NO_QUERY
# 558391        0  2204735567  Wed Jun 17 03:00:02 PDT 2009  NO_QUERY
# 820010        4  1553585468  Sat Apr 18 14:39:59 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 541200   LaLaLindsey0609             @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750          sexygrneyes  @misstoriblack cool , i have no tweet apps  fo...
# 766711        sammydearr  @TiannaChaos i know  just family drama. its la...
# 285055       Lamb_Leanne  School email won't open  and I have geography ...
# 705995       yogicerdito                             upper airways problem
# 379611         Yengching         Going to miss Pastor's sermon on Faith...
# 1189018         jessig06            on lunch....dj should come eat with me
# 667030    felicityfuller   @piginthepoke oh why are you feeling like that?
# 93541        stephiiheyy    gahh noo!peyton needs to live!this is horrible
# 1097326        wyndwitch  @mrstessyman thank you glad you like it! There...
# 1380171         salmafan  @PerezHilton Zach makes me pee sitting down! A...
# 1233933       spanishman  to sum up my day in one word ......... kackered!
# 1495501     DannyMacRant                    @k9wkj Great minds think alike
# 558391      Arabellakind                             Is Poorly and in bed!
# 820010            Reisei  @LilPecan Oh, that's really great  Here we hav...
#
#                                             text_processed
# 541200   [(chrishasboob, chrishasboobs), (ahhh, ahhh), ...
# 750      [(misstoriblack, misstoriblack), (cool, cool),...
# 766711   [(tiannachao, tiannachaos), (i, i), (know, kno...
# 285055   [(school, school), (email, email), (won, won),...
# 705995   [(upper, upper), (airway, airway), (problem, p...
# 379611   [(go, going), (to, to), (miss, miss), (pastor,...
# 1189018  [(on, on), (lunch, lunch), (dj, dj), (should, ...
# 667030   [(piginthepok, piginthepoke), (oh, oh), (whi, ...
# 93541    [(gahh, gahh), (noo, noo), (peyton, peyton), (...
# 1097326  [(mrstessyman, mrstessyman), (thank, thank), (...
# 1380171  [(perezhilton, perezhilton), (zach, zach), (ma...
# 1233933  [(to, to), (sum, sum), (up, up), (my, my), (da...
# 1495501  [(k, k), (wkj, wkj), (great, great), (mind, mi...
# 558391   [(is, is), (poorli, poorly), (and, and), (in, ...
# 820010   [(lilpecan, lilpecan), (oh, oh), (that, that),...

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# Selecting the 5000 words with the most frequency:

from nltk.probability import FreqDist

all_words = [word for sublist in df_subset['text_processed'] for word in sublist]

freq_dist = FreqDist(all_words)

top_words = freq_dist.most_common(5000)

top_words = [word[0] for word in top_words]

# %%
print(top_words)
# Out:
# [('i', 'i'), ('to', 'to'), ('the', 'the'), ('a', 'a'), ('it', 'it'), ('my', 'my'), ('you', 'you'), ('and', 'and'), ('is', 'is'), ('for', 'for'), ('in', 'in'), ('s', 's'), ('t', 't'), ('of', 'of'), ('on', 'on'), ('me', 'me'), ('that', 'that'), ('so', 'so'), ('have', 'have'), ('m', 'm'), ('but', 'but'), ('just', 'just'), ('with', 'with'), ('not', 'not'), ('be', 'be'), ('at', 'at'), ('wa', 'wa'), ('day', 'day'), ('can', 'can'), ('thi', 'this'), ('good', 'good'), ('now', 'now'), ('up', 'up'), ('get', 'get'), ('out', 'out'), ('all', 'all'), ('are', 'are'), ('like', 'like'), ('quot', 'quot'), ('no', 'no'), ('go', 'go'), ('today', 'today'), ('got', 'got'), ('work', 'work'), ('do', 'do'), ('love', 'love'), ('your', 'your'), ('time', 'time'), ('too', 'too'), ('we', 'we'), ('go', 'going'), ('lol', 'lol'), ('what', 'what'), ('one', 'one'), ('from', 'from'), ('know', 'know'), ('back', 'back'), ('am', 'am'), ('will', 'will'), ('don', 'don'), ('about', 'about'), ('u', 'u'), ('realli', 'really'), ('want', 'want'), ('amp', 'amp'), ('there', 'there'), ('im', 'im'), ('some', 'some'), ('well', 'well'), ('they', 'they'), ('still', 'still'), ('see', 'see'), ('night', 'night'), ('had', 'had'), ('think', 'think'), ('if', 'if'), ('oh', 'oh'), ('thank', 'thanks'), ('na', 'na'), ('as', 'a'), ('he', 'he'), ('home', 'home'), ('how', 'how'), ('when', 'when'), ('ll', 'll'), ('need', 'need'), ('new', 'new'), ('more', 'more'), ('here', 'here'), ('miss', 'miss'), ('hope', 'hope'), ('an', 'an'), ('feel', 'feel'), ('ha', 'ha'), ('last', 'last'), ('off', 'off'), ('much', 'much'), ('make', 'make'), ('re', 're'), ('great', 'great'), ('twitter', 'twitter'), ('or', 'or'), ('morn', 'morning'), ('again', 'again'), ('been', 'been'), ('she', 'she'), ('tomorrow', 'tomorrow'), ('then', 'then'), ('her', 'her'), ('haha', 'haha'), ('wish', 'wish'), ('week', 'week'), ('sad', 'sad'), ('sleep', 'sleep'), ('sorri', 'sorry'), ('come', 'come'), ('bad', 'bad'), ('onli', 'only'), ('veri', 'very'), ('happi', 'happy'), ('would', 'would'), ('right', 'right'), ('whi', 'why'), ('fun', 'fun'), ('tonight', 'tonight'), ('by', 'by'), ('say', 'say'), ('should', 'should'), ('ve', 've'), ('friend', 'friend'), ('thing', 'thing'), ('better', 'better'), ('nice', 'nice'), ('though', 'though'), ('did', 'did'), ('look', 'look'), ('watch', 'watching'), ('them', 'them'), ('bed', 'bed'), ('d', 'd'), ('over', 'over'), ('get', 'getting'), ('gon', 'gon'), ('peopl', 'people'), ('who', 'who'), ('way', 'way'), ('hate', 'hate'), ('wait', 'wait'), ('school', 'school'), ('yeah', 'yeah'), ('lt', 'lt'), ('could', 'could'), ('dont', 'dont'), ('hour', 'hour'), ('awesom', 'awesome'), ('after', 'after'), ('didn', 'didn'), ('even', 'even'), ('first', 'first'), ('everyon', 'everyone'), ('show', 'show'), ('guy', 'guy'), ('next', 'next'), ('him', 'him'), ('work', 'working'), ('weekend', 'weekend'), ('watch', 'watch'), ('year', 'year'), ('soon', 'soon'), ('littl', 'little'), ('were', 'were'), ('tweet', 'tweet'), ('take', 'take'), ('down', 'down'), ('ye', 'yes'), ('let', 'let'), ('long', 'long'), ('never', 'never'), ('pleas', 'please'), ('thank', 'thank'), ('girl', 'girl'), ('wan', 'wan'), ('have', 'having'), ('hey', 'hey'), ('x', 'x'), ('cant', 'cant'), ('do', 'doing'), ('ok', 'ok'), ('movi', 'movie'), ('be', 'being'), ('done', 'done'), ('man', 'man'), ('best', 'best'), ('where', 'where'), ('hi', 'his'), ('find', 'find'), ('life', 'life'), ('us', 'u'), ('alway', 'always'), ('ani', 'any'), ('sick', 'sick'), ('tire', 'tired'), ('our', 'our'), ('alreadi', 'already'), ('sure', 'sure'), ('feel', 'feeling'), ('phone', 'phone'), ('becaus', 'because'), ('anoth', 'another'), ('look', 'looking'), ('n', 'n'), ('than', 'than'), ('mayb', 'maybe'), ('made', 'made'), ('suck', 'suck'), ('thought', 'thought'), ('start', 'start'), ('old', 'old'), ('lot', 'lot'), ('song', 'song'), ('someth', 'something'), ('cool', 'cool'), ('follow', 'follow'), ('game', 'game'), ('keep', 'keep'), ('help', 'help'), ('bit', 'bit'), ('went', 'went'), ('amaz', ' ...

# %%
len(top_words)
# Out:
# 5000

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# Creating the 2D matrix:

features = []


for index, row in df_subset.iterrows():
   
    tweet_text = row['text']
    
   
    word_presence = {word: (word in tweet_text.split()) for word, _ in top_words}
    
    
    features.append((word_presence, row['target'] == 4))

# %%
features[:1]
# Out:
# [({'i': False,
#    'to': False,
#    'the': False,
#    'a': False,
#    'it': False,
#    'my': False,
#    'you': False,
#    'and': False,
#    'is': False,
#    'for': False,
#    'in': False,
#    's': False,
#    't': False,
#    'of': False,
#    'on': False,
#    'me': False,
#    'that': False,
#    'so': False,
#    'have': False,
#    'm': False,
#    'but': False,
#    'just': False,
#    'with': False,
#    'not': False,
#    'be': False,
#    'at': False,
#    'wa': False,
#    'day': False,
#    'can': False,
#    'thi': False,
#    'good': False,
#    'now': False,
#    'up': False,
#    'get': False,
#    'out': False,
#    'all': False,
#    'are': False,
#    'like': False,
#    'quot': False,
#    'no': False,
#    'go': False,
#    'today': False,
#    'got': False,
#    'work': False,
#    'do': False,
#    'love': False,
#    'your': False,
#    'time': False,
#    'too': False,
#    'we': False,
#    'lol': False,
#    'what': False,
#    'one': False,
#    'from': False,
#    'know': False,
#    'back': False,
#    'am': False,
#    'will': False,
#    'don': False,
#    'about': False,
#    'u': False,
#    'realli': False,
#    'want': False,
#    'amp': False,
#    'there': False,
#    'im': False,
#    'some': False,
#    'well': False,
#    'they': False,
#    'still': False,
#    'see': False,
#    'night': False,
#    'had': False,
#    'think': False,
#    'if': False,
#    'oh': False,
#    'thank': False,
#    'na': False,
#    'as': False,
#    'he': False,
#    'home': False,
#    'how': False,
#    'when': False,
#    'll': False,
#    'need': False,
#    'new': False,
#    'more': False,
#    'here': False,
#    'miss': False,
#    'hope': False,
#    'an': False,
#    'feel': False,
#    'ha': False,
#    'last': False,
#    'off': False,
#    'much': False,
#    'make': False,
#    're': False,
#    'great': False,
#    'twitter': False,
#    'or': False,
#    'morn': False,
#    'again': False,
#    'been': False,
#    'she': False,
#    'tomorrow': False,
#    'then': False,
#    'her': False,
#    'haha': False,
#    'wish': False,
#    'week': False,
#    'sad': False,
#    'sleep': False,
#    'sorri': False,
#    'come': False,
#    'bad': False,
#    'onli': False,
#    'veri': False,
#    'happi': False,
#    'would': False,
#    'right': False,
#    'whi': False,
#    'fun': False,
#    'tonight': False,
#    'by': False,
#    'say': False,
#    'should': False,
#    've': False,
#    'friend': False,
#    'thing': False,
#    'better': False,
#    'nice': False,
#    'though': False,
#    'did': False,
#    'look': False,
#    'watch': False,
#    'them': False,
#    'bed': False,
#    'd': False,
#    'over': False,
#    'gon': False,
#    'peopl': False,
#    'who': False,
#    'way': False,
#    'hate': False,
#    'wait': False,
#    'school': False,
#    'yeah': False,
#    'lt': False,
#    'could': False,
#    'dont': False,
#    'hour': False,
#    'awesom': False,
#    'after': False,
#    'didn': False,
#    'even': False,
#    'first': False,
#    'everyon': False,
#    'show': False,
#    'guy': False,
#    'next': False,
#    'him': False,
#    'weekend': False,
#    'year': False,
#    'soon': False,
#    'littl': False,
#    'were': False,
#    'tweet': False,
#    'take': False,
#    'down': False,
#    'ye': False,
#    'let': False,
#    'long': False,
#    'never': False,
#    'pleas': False,
#    'girl': False,
#    'wan': False,
#    'hey': False,
#    'x': False,
#    'cant': False,
#    'ok': False,
#    'movi': False,
#    'done': False,
#    'man': False,
#    'best': False,
#    'where': False,
#    'hi': False,
#    'find': False,
#    'life': False,
#    'us': False,
#    'alway': False,
#    'ani': False,
#    'sick': False,
#    'tire': False,
#    'our': False,
#    'alreadi': False,
#    'sure': False,
#    'phone': False,
#    'becaus': False,
#    'anoth': False,
#    'n': False,
#    'than': False,
#    'mayb': False,
#    'made': False,
#    'suck': False,
#    'thought': False,
#    'start': False,
#    'old': False,
#    'lot': False,
#    'song': False,
#    'someth': False,
#    'cool': False,
#    'follow': False,
#    'game': False,
#    'keep': False,
#    'help': False,
#    'bit': False,
#    'went': False,
#    'amaz': False,
#    'yay': False,
#    'away': False,
#    'yet': False,
#    'pretti': False,
#    'won': False,
#    'sound': False,
#    'befor': False,
#    'tri': False,
#    'final': False,
#    'wow': False,
#    'readi': False,
#    'hurt': False,
#    'earli': False,
#    'big': False,
#    'other': False,
#    'ever': False,
#    'while': False,
#    'parti': False,
#    'omg': False,
#    'ur': False,
#    'w': False,
#    'hous': False,
#    'lost': False,
#    'birthday': False,
#    'pic': False,
#    'rain': False,
#    'into': False,
#    'damn': False,
#    'those': False,
#    'guess': False,
#    'live': False,
#    'also': False,
#    'said': False,
#    'hot': False,
#    'left': False,
#    'noth': False,
#    'bore': False,
#    'ugh': False,
#    'babi': False,
#    'exam': False,
#    'friday': False,
#    'mean': False,
#    'world': False,
#    'stuff': False,
#    'same': False,
#    'ya': False,
#    'mani': False,
#    'glad': False,
#    'sinc': False,
#    'play': False,
#    'aww': False,
#    'such': False,
#    'someon': False,
#    'excit': False,
#    'b': False,
#    'might': False,
#    'weather': False,
#    'actual': False,
#    'doe': False,
#    'summer': False,
#    'doesn': False,
#    'tell': False,
#    'must': False,
#    'hear': False,
#    'monday': False,
#    'until': False,
#    'hair': False,
#    'com': False,
#    'famili': False,
#    'th': False,
#    'mom': False,
#    'found': False,
#    'around': False,
#    'ta': False,
#    'may': False,
#    'call': False,
#    'tho': False,
#    'sun': False,
#    'o': False,
#    'check': False,
#    'god': False,
#    'sunday': False,
#    'dinner': False,
#    'boy': False,
#    'car': False,
#    'luck': False,
#    'iphon': False,
#    'saw': False,
#    'head': False,
#    'later': False,
#    'job': False,
#    'read': False,
#    'few': False,
#    'hard': False,
#    'free': False,
#    'give': False,
#    'yesterday': False,
#    'isn': False,
#    'pictur': False,
#    'sweet': False,
#    'food': False,
#    'stop': False,
#    'forward': False,
#    'beauti': False,
#    'use': False,
#    'listen': False,
#    'put': False,
#    'least': False,
#    'everyth': False,
#    'r': False,
#    'late': False,
#    'poor': False,
#    'music': False,
#    'leav': False,
#    'kid': False,
#    'end': False,
#    'video': False,
#    'cold': False,
#    'most': False,
#    'place': False,
#    'myself': False,
#    'woke': False,
#    'till': False,
#    'gone': False,
#    'stay': False,
#    'sooo': False,
#    'okay': False,
#    'their': False,
#    'eat': False,
#    'anyth': False,
#    'lunch': False,
#    'win': False,
#    'month': False,
#    'cute': False,
#    'wrong': False,
#    'two': False,
#    'ill': False,
#    'room': False,
#    'shit': False,
#    'dad': False,
#    'onc': False,
#    'p': False,
#    'anyon': False,
#    'hahaha': False,
#    'which': False,
#    'haven': False,
#    'gt': False,
#    'cri': False,
#    'caus': False,
#    'believ': False,
#    'far': False,
#    'enjoy': False,
#    'without': False,
#    'almost': False,
#    'fan': False,
#    'idea': False,
#    'finish': False,
#    'headach': False,
#    'money': False,
#    'probabl': False,
#    'funni': False,
#    'name': False,
#    'book': False,
#    'came': False,
#    'talk': False,
#    'updat': False,
#    'hehe': False,
#    'class': False,
#    'goodnight': False,
#    'saturday': False,
#    'stupid': False,
#    'tv': False,
#    'dog': False,
#    'mother': False,
#    'whole': False,
#    'pm': False,
#    'minut': False,
#    'cours': False,
#    'photo': False,
#    'enough': False,
#    'didnt': False,
#    'part': False,
#    'post': False,
#    'dream': False,
#    'half': False,
#    'anymor': False,
#    'xx': False,
#    'seem': False,
#    'real': False,
#    'blog': False,
#    'either': False,
#    'â': False,
#    'boo': False,
#    'word': False,
#    'these': False,
#    'serious': False,
#    'through': False,
#    'run': False,
#    'buy': False,
#    'sit': False,
#    'true': False,
#    'mine': False,
#    'meet': False,
#    'welcom': False,
#    'everi': False,
#    'ð': False,
#    'awww': False,
#    'kinda': False,
#    'both': False,
#    'soo': False,
#    'rock': False,
#    'text': False,
#    'rest': False,
#    'wont': False,
#    'total': False,
#    'coffe': False,
#    'brother': False,
#    'send': False,
#    'mileycyru': False,
#    'news': False,
#    'e': False,
#    'outsid': False,
#    'hit': False,
#    'www': False,
#    'full': False,
#    'hand': False,
#    'els': False,
#    'alon': False,
#    'pain': False,
#    'site': False,
#    'seen': False,
#    'fail': False,
#    'repli': False,
#    'plan': False,
#    'hello': False,
#    'concert': False,
#    'busi': False,
#    'super': False,
#    'face': False,
#    'ticket': False,
#    'forgot': False,
#    'heart': False,
#    'ñ': False,
#    'email': False,
#    'trip': False,
#    'beach': False,
#    'heard': False,
#    'rememb': False,
#    'la': False,
#    'person': False,
#    'abl': False,
#    'quit': False,
#    'eye': False,
#    'comput': False,
#    'problem': False,
#    'add': False,
#    'walk': False,
#    'train': False,
#    'wasn': False,
#    'internet': False,
#    'onlin': False,
#    'stuck': False,
#    'afternoon': False,
#    'june': False,
#    'c': False,
#    'bought': False,
#    'cut': False,
#    'crazi': False,
#    'link': False,
#    'offic': False,
#    'nite': False,
#    'ice': False,
#    'fuck': False,
#    'chang': False,
#    'break': False,
#    'turn': False,
#    'star': False,
#    'btw': False,
#    'took': False,
#    'lmao': False,
#    'ask': False,
#    'instead': False,
#    'hug': False,
#    'anyway': False,
#    'kind': False,
#    'shop': False,
#    'ah': False,
#    'told': False,
#    'sunni': False,
#    'cuz': False,
#    'open': False,
#    'y': False,
#    'hell': False,
#    'g': False,
#    'pay': False,
#    'season': False,
#    'nap': False,
#    'worri': False,
#    'wonder': False,
#    'awak': False,
#    'care': False,
#    'dead': False,
#    'laptop': False,
#    'co': False,
#    'ago': False,
#    'shower': False,
#    'page': False,
#    'sister': False,
#    'togeth': False,
#    'l': False,
#    'test': False,
#    'drive': False,
#    'yea': False,
#    'wake': False,
#    'mind': False,
#    'red': False,
#    'cat': False,
#    'side': False,
#    'dude': False,
#    'top': False,
#    'congrat': False,
#    'couldn': False,
#    'water': False,
#    'award': False,
#    'crap': False,
#    'project': False,
#    'album': False,
#    'breakfast': False,
#    'uk': False,
#    'move': False,
#    'jealou': False,
#    'date': False,
#    'holiday': False,
#    'bring': False,
#    'team': False,
#    'worth': False,
#    'bout': False,
#    'drink': False,
#    'homework': False,
#    'account': False,
#    'k': False,
#    'fine': False,
#    'hungri': False,
#    'moment': False,
#    'youtub': False,
#    'mad': False,
#    'favorit': False,
#    'tommcfli': False,
#    'ass': False,
#    'catch': False,
#    'mr': False,
#    'town': False,
#    'fall': False,
#    'english': False,
#    'goin': False,
#    'st': False,
#    'asleep': False,
#    'facebook': False,
#    'danc': False,
#    'soooo': False,
#    'ladi': False,
#    'shirt': False,
#    'ate': False,
#    'park': False,
#    'sunshin': False,
#    'happen': False,
#    'second': False,
#    'past': False,
#    'card': False,
#    'die': False,
#    'dear': False,
#    'gym': False,
#    'f': False,
#    'forget': False,
#    'reason': False,
#    'band': False,
#    'load': False,
#    'vote': False,
#    'bye': False,
#    'sat': False,
#    'air': False,
#    'wouldn': False,
#    'mood': False,
#    'definit': False,
#    'aren': False,
#    'nd': False,
#    'wed': False,
#    'parent': False,
#    'tour': False,
#    'sometim': False,
#    'hang': False,
#    'appar': False,
#    'aw': False,
#    'fb': False,
#    'high': False,
#    'comment': False,
#    'store': False,
#    'church': False,
#    'ddlovato': False,
#    'smile': False,
#    'appl': False,
#    'fix': False,
#    'lazi': False,
#    'stori': False,
#    'bet': False,
#    'clean': False,
#    'mum': False,
#    'broke': False,
#    'cream': False,
#    'own': False,
#    'light': False,
#    'visit': False,
#    'power': False,
#    'vacat': False,
#    'sigh': False,
#    'write': False,
#    'flight': False,
#    'ipod': False,
#    'lucki': False,
#    'min': False,
#    'close': False,
#    'ahh': False,
#    'studi': False,
#    'black': False,
#    'dress': False,
#    'fast': False,
#    'fair': False,
#    'suppos': False,
#    'point': False,
#    'line': False,
#    'download': False,
#    'sent': False,
#    'xd': False,
#    'due': False,
#    'understand': False,
#    'blue': False,
#    'rather': False,
#    'slow': False,
#    'hmm': False,
#    'coupl': False,
#    'laker': False,
#    'set': False,
#    'sore': False,
#    'met': False,
#    'messag': False,
#    'ive': False,
#    'math': False,
#    'list': False,
#    'chocol': False,
#    'citi': False,
#    'horribl': False,
#    'unfortun': False,
#    'em': False,
#    'chanc': False,
#    'short': False,
#    'ppl': False,
#    'window': False,
#    'dure': False,
#    'perfect': False,
#    'gave': False,
#    'ride': False,
#    'til': False,
#    'interest': False,
#    'agre': False,
#    'answer': False,
#    'weird': False,
#    'question': False,
#    'easi': False,
#    'nope': False,
#    'bike': False,
#    'support': False,
#    'shot': False,
#    'followfriday': False,
#    'throat': False,
#    'wear': False,
#    'colleg': False,
#    'idk': False,
#    'pool': False,
#    'under': False,
#    'none': False,
#    'forev': False,
#    'insid': False,
#    'upset': False,
#    'myspac': False,
#    'chicken': False,
#    'bbq': False,
#    'shame': False,
#    'tea': False,
#    'scare': False,
#    'london': False,
#    'issu': False,
#    'flu': False,
#    'especi': False,
#    'yep': False,
#    'road': False,
#    'cd': False,
#    'worst': False,
#    'earlier': False,
#    'yummi': False,
#    'son': False,
#    'miley': False,
#    'knew': False,
#    'order': False,
#    'special': False,
#    'beat': False,
#    'da': False,
#    'goe': False,
#    'camera': False,
#    'small': False,
#    'less': False,
#    'xxx': False,
#    'green': False,
#    'hr': False,
#    'pizza': False,
#    'differ': False,
#    'dm': False,
#    'hospit': False,
#    'bu': False,
#    'gorgeou': False,
#    'sleepi': False,
#    'sadli': False,
#    'spent': False,
#    'via': False,
#    'thursday': False,
#    'yr': False,
#    'plz': False,
#    'slept': False,
#    'case': False,
#    'bodi': False,
#    'finger': False,
#    'death': False,
#    'v': False,
#    'bitch': False,
#    'wednesday': False,
#    'bank': False,
#    'pick': False,
#    'share': False,
#    'yourself': False,
#    'three': False,
#    'wors': False,
#    'lone': False,
#    'ahhh': False,
#    'lame': False,
#    'yo': False,
#    'touch': False,
#    'ps': False,
#    'number': False,
#    'dang': False,
#    'compani': False,
#    'garden': False,
#    'spend': False,
#    'mtv': False,
#    'save': False,
#    'wtf': False,
#    'everybodi': False,
#    'magic': False,
#    'hahahaha': False,
#    'fell': False,
#    'ear': False,
#    'tom': False,
#    'bday': False,
#    'figur': False,
#    'join': False,
#    'tummi': False,
#    'å': False,
#    'box': False,
#    'episod': False,
#    'luv': False,
#    'xoxo': False,
#    'websit': False,
#    'babe': False,
#    'chat': False,
#    'annoy': False,
#    'mac': False,
#    'graduat': False,
#    'hotel': False,
#    'doctor': False,
#    'paper': False,
#    'storm': False,
#    'huge': False,
#    'stomach': False,
#    'web': False,
#    'film': False,
#    'airport': False,
#    'smell': False,
#    'servic': False,
#    'white': False,
#    'shoe': False,
#    'tuesday': False,
#    'offici': False,
#    'fact': False,
#    'eh': False,
#    'woo': False,
#    'low': False,
#    'jona': False,
#    'sold': False,
#    'sim': False,
#    'isnt': False,
#    'countri': False,
#    'kate': False,
#    'bro': False,
#    'daughter': False,
#    'interview': False,
#    'shall': False,
#    'channel': False,
#    'jonasbroth': False,
#    'cheer': False,
#    'learn': False,
#    'blood': False,
#    'david': False,
#    'teeth': False,
#    'feet': False,
#    'broken': False,
#    'lesson': False,
#    'although': False,
#    'exactli': False,
#    'often': False,
#    'boot': False,
#    'gay': False,
#    'fever': False,
#    'cloth': False,
#    'pack': False,
#    'chillin': False,
#    'version': False,
#    'absolut': False,
#    'meant': False,
#    'round': False,
#    'sooooo': False,
#    'hubbi': False,
#    'voic': False,
#    'mail': False,
#    'major': False,
#    'plu': False,
#    'snow': False,
#    'hun': False,
#    'id': False,
#    'type': False,
#    'beer': False,
#    'chicago': False,
#    'cousin': False,
#    'nose': False,
#    'hold': False,
#    'mobil': False,
#    'sale': False,
#    'topic': False,
#    'thx': False,
#    'street': False,
#    'longer': False,
#    'cake': False,
#    'art': False,
#    'along': False,
#    'bag': False,
#    'lil': False,
#    'laugh': False,
#    'safe': False,
#    'view': False,
#    'behind': False,
#    'taken': False,
#    'roll': False,
#    'vip': False,
#    'ma': False,
#    'hangov': False,
#    'raini': False,
#    'kill': False,
#    'upload': False,
#    '½': False,
#    'except': False,
#    'club': False,
#    'leg': False,
#    'proud': False,
#    'h': False,
#    'whatev': False,
#    'pass': False,
#    'note': False,
#    'ball': False,
#    'peac': False,
#    'revis': False,
#    'wife': False,
#    'lose': False,
#    'bloodi': False,
#    'traffic': False,
#    'camp': False,
#    'sign': False,
#    'watchin': False,
#    'huh': False,
#    'nobodi': False,
#    'puppi': False,
#    'awwww': False,
#    'jon': False,
#    'fat': False,
#    'radio': False,
#    'warm': False,
#    'dvd': False,
#    'gettin': False,
#    'apart': False,
#    'boyfriend': False,
#    'ouch': False,
#    'review': False,
#    'alright': False,
#    'fantast': False,
#    'door': False,
#    'doesnt': False,
#    'felt': False,
#    'peep': False,
#    'futur': False,
#    'realiz': False,
#    'against': False,
#    'choic': False,
#    'piss': False,
#    'fam': False,
#    'kiss': False,
#    'tweep': False,
#    'tear': False,
#    'epic': False,
#    'fault': False,
#    'inde': False,
#    'doubl': False,
#    'knee': False,
#    'tweetdeck': False,
#    'scari': False,
#    'pc': False,
#    'ahead': False,
#    'freak': False,
#    'batteri': False,
#    'ooh': False,
#    'j': False,
#    'throw': False,
#    'darn': False,
#    'havent': False,
#    'each': False,
#    'moon': False,
#    'pink': False,
#    'glass': False,
#    'afraid': False,
#    'msn': False,
#    'nail': False,
#    'age': False,
#    'app': False,
#    'pray': False,
#    'million': False,
#    'mouth': False,
#    'hmmm': False,
#    'tast': False,
#    'aint': False,
#    'mmm': False,
#    'tonit': False,
#    'mommi': False,
#    'profil': False,
#    'king': False,
#    'fish': False,
#    'bill': False,
#    'bath': False,
#    'wit': False,
#    'joe': False,
#    'releas': False,
#    'articl': False,
#    'drop': False,
#    'depress': False,
#    'father': False,
#    'couldnt': False,
#    'feelin': False,
#    'terribl': False,
#    'usual': False,
#    'block': False,
#    'starbuck': False,
#    'race': False,
#    'excel': False,
#    'milk': False,
#    'alot': False,
#    'nearli': False,
#    'rd': False,
#    'troubl': False,
#    'swim': False,
#    'boss': False,
#    'taylor': False,
#    'dark': False,
#    'promis': False,
#    'appreci': False,
#    'si': False,
#    'brain': False,
#    'arm': False,
#    ...},
#   False)]

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# Selecting 90% for the train set and 10% for the test set:

train_size = int(0.9 * len(features))
train_set, test_set = features[:train_size], features[train_size:]

# %%
# Training the model:

import nltk

classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                      sad = True            False : True   =     17.0 : 1.0
#                     poor = True            False : True   =     16.9 : 1.0
#                     pain = True            False : True   =     14.3 : 1.0
#                      ugh = True            False : True   =     13.1 : 1.0
#                    shame = True            False : True   =     11.8 : 1.0
#                     sick = True            False : True   =     11.6 : 1.0
#                   anyway = True             True : False  =     11.6 : 1.0
#                     sore = True            False : True   =     10.7 : 1.0
#                    burnt = True            False : True   =      9.7 : 1.0
#                  stomach = True            False : True   =      9.5 : 1.0
#                     sing = True             True : False  =      8.3 : 1.0
#                    blood = True            False : True   =      7.7 : 1.0
#                     hate = True            False : True   =      7.5 : 1.0
#                   broken = True            False : True   =      7.5 : 1.0
#                     suck = True            False : True   =      7.5 : 1.0

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# Testing NBModel:

print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, test_set))*100)
# Out:
# Classifier accuracy percent: 66.55
